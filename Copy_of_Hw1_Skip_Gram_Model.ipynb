# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhamd13/NLP/blob/main/Copy_of_Hw1_Skip_Gram_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW1: Skip-Gram Model From Scratch

# %%
# %matplotlib inline
# put your student name here, you will need to train the model that prints out your name in each loss
# without the name, you will not be able to get points in train part
STUDENT_NAME = "Shubham Derhgawen"

# %% [markdown]
# This section imports necessary Python libraries such as NumPy and the random module. These libraries are essential for generating random training data and managing numerical computations.

# %%
import numpy as np
import random
np.random.seed(0)
random.seed(0)

# %% [markdown]
# ### 1.Create Corpus
#
# In this section, you should first define a custom vocabulary composed of universities in Southern California (SoCal) and Northern California (NorCal). It generates a synthetic corpus by randomly pairing elements within each regional list to simulate word-context relationships.

# %%
SoCal = ["UCR", "UCLA", "UCSD", "UCI", "UCSB"]
NorCal = ["UCB", "UCSC", "UCD", "UCSF", "UCM"]
vocab = SoCal + NorCal

corpus = []

# Create Corpus
for i in range(20):
  random.shuffle(SoCal)
  corpus.append((SoCal[0], SoCal[1]))

for i in range(20):
  random.shuffle(NorCal)
  corpus.append((NorCal[0], NorCal[1]))

word_to_index = {word: i for i, word in enumerate(vocab)}
index_to_word = {i: word for i, word in enumerate(vocab)}

vocab_size = len(vocab)

embedding_dim = 2
learning_rate = 0.02
num_neg_samples = 2

print(corpus)
# Out:
# [('UCSD', 'UCLA'), ('UCSD', 'UCR'), ('UCR', 'UCSD'), ('UCI', 'UCR'), ('UCR', 'UCSB'), ('UCSB', 'UCLA'), ('UCLA', 'UCSB'), ('UCI', 'UCLA'), ('UCI', 'UCSB'), ('UCLA', 'UCSB'), ('UCR', 'UCI'), ('UCI', 'UCLA'), ('UCI', 'UCR'), ('UCSB', 'UCSD'), ('UCI', 'UCSD'), ('UCSD', 'UCSB'), ('UCLA', 'UCSD'), ('UCSB', 'UCLA'), ('UCR', 'UCI'), ('UCLA', 'UCSD'), ('UCSF', 'UCD'), ('UCB', 'UCD'), ('UCM', 'UCSC'), ('UCM', 'UCD'), ('UCSF', 'UCB'), ('UCB', 'UCSC'), ('UCSC', 'UCD'), ('UCSC', 'UCB'), ('UCB', 'UCSF'), ('UCSF', 'UCD'), ('UCM', 'UCSC'), ('UCSC', 'UCD'), ('UCM', 'UCSC'), ('UCD', 'UCM'), ('UCM', 'UCB'), ('UCB', 'UCD'), ('UCM', 'UCB'), ('UCB', 'UCD'), ('UCB', 'UCSC'), ('UCSF', 'UCB')]

# %% [markdown]
# ### 2.Define Visualization Function
#
# Implement plotting utilities for visualizing training loss, embedding space, and cosine similarity between word vectors. (No Need to Change.)

# %%
import matplotlib.pyplot as plt

# Plot loss over epochs
def plot_loss_over_epochs(loss_values, epochs):
  plt.figure(figsize=(6, 4))
  plt.plot(range(1, epochs + 1), loss_values, marker='o')
  plt.ticklabel_format(style='plain', axis='y', useOffset=False)
  plt.xlabel('Epoch')
  plt.ylabel('Average Loss')
  plt.title('Loss over Epochs')
  plt.show()

# Plot Embedding
def plot_embedding(matrix, vocab):
  plt.figure(figsize=(6, 4))
  x = matrix[:, 0]
  y = matrix[:, 1]
  plt.scatter(x, y)
  for i, word in enumerate(vocab):
    plt.annotate(word, xy=(x[i], y[i]))

  plt.title("Embedding Visualization")
  plt.show()

# Plot Similary score
def plot_cosine_similarity(matrix, vocab):

  def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

  similarities = np.array([
      cosine_similarity(matrix[0], emb) for emb in matrix
  ])

  plt.figure(figsize=(6, 4))
  plt.bar(range(len(similarities)), similarities)
  plt.xticks(range(len(similarities)), vocab)
  plt.ylim(-1.1, 1.1)
  plt.ylabel("Cosine Similarity")
  plt.title("Cosine Similarity to UCR")
  plt.grid(axis='y')

  plt.show()

# %% [markdown]
# ### 3.Define trainable parameters (10pt)
#
# Use Numpy to initialize two trainable embedding matrices — one for context words and one for target words — with small random values.
#
# Here is the size for each Matrix:
#
# 1. Context Matrix:   [vocab_size, embedding_dim]
# 2. Target Matrix:  [vocab_size, embedding_dim]

# %%
def initialize_parameters(vocab_size, embedding_dim):
  # Context Matrix
  ####! add your code here
  W1 = np.random.randn(vocab_size, embedding_dim)
  ####

  # Target Matrix
  ####! add your code here
  W2 = np.random.randn(vocab_size, embedding_dim)
  ####

  return W1, W2

# visualization
W1, W2 = initialize_parameters(vocab_size, embedding_dim)
plot_embedding(W2, vocab)
plot_cosine_similarity(W2, vocab)

# %% [markdown]
# ### 4.Define Activation Function (5pt)
# Implement the sigmoid function used in the computation of prediction probabilities and gradients.
#
#
# Sigmoid Function: $\sigma(z) = \frac{1}{ 1 + exp(-z)}$

# %%
#! define sigmoid function
def sigmoid(z):
  z = np.clip(z, -100, 100)
  ####! add your code here
  z = 1 / (1 + np.exp(-z))
  return z

# %% [markdown]
# ### 5.Define Negative Sampling (15pt)
#
# Randomly select a set of negative word samples for each training instance, ensuring they differ from the current positive pair.
#
# By using negative sampling, we can improve computational efficiency by approximating the full softmax over the vocabulary.

# %%
def negative_sampling(word_to_index, target_index, context_index, num_neg_samples):
  """
  word_to_index: vocabulary.
  target_index: target word index.
  num_neg_samples: numbers of negative samples.
  """
  vocab_indices = list(word_to_index.values())
  # remove context and target tokens.
  ####! add your code here
  filtered_indices = [idx for idx in vocab_indices if idx != target_index and idx != context_index]


  ####
  # randomly choose negative words.
  ####! add your code here
  neg_samples = random.sample(filtered_indices, num_neg_samples)
  ####

  return neg_samples


# test Negative Sampling
neg_samples = negative_sampling(word_to_index, word_to_index["UCR"], word_to_index["UCLA"], num_neg_samples)
print('Negative Words:')
for sample in neg_samples:
  print(index_to_word[sample])
# Out:
# Negative Words:
# UCSD
# UCSF

# %% [markdown]
# ### 6.Forward (20pt)
# Compute the positive and negative prediction scores and calculate the loss using the negative sampling technique.
#
# Loss Function:
# $L_{CE}=-\bigg[log\sigma(c_{pos}\cdot w) + \sum_{i=1}^{k}log\sigma(-c_{neg_i}\cdot w)\bigg]$

# %%
def forward_negative_sampling(context_word_index, target_word_index, neg_samples, W1, W2):
  # obtain context vector
  h_context = W1[context_word_index]
  # obtain negative sample vector
  ####! Add your code here
  h_neg = W2[neg_samples]
  ####

  # ompute positive prediction and loss.
  u_target = np.dot(h_context, W2[target_word_index])
  ####! Add your code here
  pos_loss = -np.log(sigmoid(u_target))
  ####

  # compute negative prediction and loss.
  ####! Add your code here
  u_neg_samples = np.dot(h_neg, h_context)
  neg_loss = -np.sum(np.log(sigmoid(-u_neg_samples)))
  ####

  # total loss
  loss = pos_loss + neg_loss
  return u_target, u_neg_samples, loss

# %% [markdown]
# ### 7.Backward (20pt)
# Update model parameters using gradients derived from the loss function for both positive and negative samples.
#
# Loss Function:
#
# 1. $c^{t+1}_{pos} = c^t_{pos} - \eta [\sigma(c^t_{pos}\cdot w^t)-1]w^t$
#
# 2. $c^{t+1}_{neg} = c^t_{neg} - \eta [\sigma(c^t_{neg}\cdot w^t)]w^t$
#
# 3. $w^{t+1} = w^t - \eta \bigg[ [\sigma (c_{pos} \cdot w^t - 1)]c_{pos} + \sum_{i=1}^{k}[\sigma (c_{neg_i}\cdot w^t)] c_{neg_i}\bigg]$

# %%
def backward_negative_sampling(
      u_target,
      u_neg_samples,
      context_word_index,
      target_word_index,
      neg_samples_idx,
      W1,
      W2,
      learning_rate):
  """
  u_target: positive prediction.
  u_negative_samples: negative predictions.
  target_word_index: positive prediction word.
  neg_samples_idx: negative prediction words.
  W1: Embedding matrix.
  W2: Projection matrix.
  """
  # positive gradient.
  grad_pos = sigmoid(u_target) - 1
  W2[target_word_index] -= learning_rate * grad_pos * W1[context_word_index]
  ####! Add your code here
  W1[context_word_index] -= learning_rate * grad_pos * W2[target_word_index]
  ####

  # negative gradient.
  ####! Add your code here
  grad_neg = sigmoid(u_neg_samples)
  ####

  for i, neg_index in enumerate(neg_samples_idx):
      ####! Add your code here
      W2[neg_index] -= learning_rate * grad_neg[i] * W1[context_word_index]
      W1[context_word_index] -= learning_rate * grad_neg[i] * W2[neg_index]
      ####

# %% [markdown]
# ### 8.Train Skip-Gram Model (20pt)
#
# Loop through the corpus over multiple epochs, applying forward and backward passes to learn word embeddings. You can train the model to produce meaningful word embeddings that capture contextual similarities.

# %%
def train_skip_gram_negative_sampling(corpus, word_to_index, vocab_size, embedding_dim, learning_rate, epochs, num_neg_samples):
  """
  corpus: Training corpus.
  word_to_index: vocabulary.
  vocab_size: Size of vocabulary.
  embedding_dim: Dimension of Embedding matrix.
  learning_rate: learning rate for optimization.
  epochs: Training epochs.
  num_neg_samples: numbers of negative samples used during training.
  """
  # init parameters
  W1, W2 = initialize_parameters(vocab_size, embedding_dim)
  total_loss = []
  for epoch in range(epochs):
      loss_epoch = 0
      for context_word, target_word in corpus:

          # convert to index.
          context_word_index = word_to_index[context_word]
          target_word_index = word_to_index[target_word]

          # Obtain negative samples.
          ####! Add your code here
          neg_samples_index = negative_sampling(word_to_index, target_word_index, context_word_index, num_neg_samples)
          ####

          # Forward
          ####! Add your code here
          u_target, u_neg_samples, loss = forward_negative_sampling(context_word_index, target_word_index, neg_samples_index, W1, W2)
          ####
          loss_epoch += loss

          # Backward
          ####! Add your code here
          backward_negative_sampling(
            u_target,
            u_neg_samples,
            context_word_index,
            target_word_index,
            neg_samples_index,
            W1,
            W2,
            learning_rate)


          ####

      avg_loss = loss_epoch / len(corpus)
      print(f"{STUDENT_NAME} Epoch {epoch+1}/{epochs}, Loss: {avg_loss}")
      total_loss.append(avg_loss)

  return W1, W2, total_loss

# %% [markdown]
# ### 9.Run Skip-Gram Model
#
# Executes the training process and visualizes the final word embeddings.

# %%
epochs = 10
W1, W2, total_loss = train_skip_gram_negative_sampling(corpus, word_to_index, vocab_size, embedding_dim, learning_rate, epochs, num_neg_samples)
plot_embedding(W1, vocab)
plot_loss_over_epochs(total_loss, epochs)
plot_cosine_similarity(W2, vocab)
# Out:
# Shubham Derhgawen Epoch 1/10, Loss: 2.338088123394384
# Shubham Derhgawen Epoch 2/10, Loss: 2.57979320471462
# Shubham Derhgawen Epoch 3/10, Loss: 2.5803478248184737
# Shubham Derhgawen Epoch 4/10, Loss: 2.183050535162604
# Shubham Derhgawen Epoch 5/10, Loss: 2.065767007911221
# Shubham Derhgawen Epoch 6/10, Loss: 2.0265336254760338
# Shubham Derhgawen Epoch 7/10, Loss: 2.155506119301165
# Shubham Derhgawen Epoch 8/10, Loss: 1.9731873606180605
# Shubham Derhgawen Epoch 9/10, Loss: 1.9621752924954674
# Shubham Derhgawen Epoch 10/10, Loss: 1.80600524638309

# %%
epochs = 100
W1, W2, total_loss = train_skip_gram_negative_sampling(corpus, word_to_index, vocab_size, embedding_dim, learning_rate, epochs, num_neg_samples)
plot_embedding(W1, vocab)
plot_loss_over_epochs(total_loss, epochs)
plot_cosine_similarity(W2, vocab)
# Out:
# Shubham Derhgawen Epoch 1/100, Loss: 3.4290519920012934
# Shubham Derhgawen Epoch 2/100, Loss: 3.0900135089454723
# Shubham Derhgawen Epoch 3/100, Loss: 2.7159179639064535
# Shubham Derhgawen Epoch 4/100, Loss: 2.634166888714813
# Shubham Derhgawen Epoch 5/100, Loss: 2.3700896159518408
# Shubham Derhgawen Epoch 6/100, Loss: 2.4381655191170486
# Shubham Derhgawen Epoch 7/100, Loss: 2.191743696305482
# Shubham Derhgawen Epoch 8/100, Loss: 2.1426656398206783
# Shubham Derhgawen Epoch 9/100, Loss: 2.135328315805505
# Shubham Derhgawen Epoch 10/100, Loss: 2.3239001535820982
# Shubham Derhgawen Epoch 11/100, Loss: 1.98585830356441
# Shubham Derhgawen Epoch 12/100, Loss: 2.111436053843585
# Shubham Derhgawen Epoch 13/100, Loss: 1.8744307572159464
# Shubham Derhgawen Epoch 14/100, Loss: 2.0375331051840453
# Shubham Derhgawen Epoch 15/100, Loss: 2.0642849344791414
# Shubham Derhgawen Epoch 16/100, Loss: 2.18214672150948
# Shubham Derhgawen Epoch 17/100, Loss: 1.9621447917725934
# Shubham Derhgawen Epoch 18/100, Loss: 2.0414395793158677
# Shubham Derhgawen Epoch 19/100, Loss: 1.9146566315217428
# Shubham Derhgawen Epoch 20/100, Loss: 1.9436986591571261
# Shubham Derhgawen Epoch 21/100, Loss: 1.9946823192647656
# Shubham Derhgawen Epoch 22/100, Loss: 1.8186530008608632
# Shubham Derhgawen Epoch 23/100, Loss: 1.897422291906945
# Shubham Derhgawen Epoch 24/100, Loss: 1.8377353029637689
# Shubham Derhgawen Epoch 25/100, Loss: 1.852876686294414
# Shubham Derhgawen Epoch 26/100, Loss: 1.8947887433779358
# Shubham Derhgawen Epoch 27/100, Loss: 1.8479102880053773
# Shubham Derhgawen Epoch 28/100, Loss: 1.9836242363350933
# Shubham Derhgawen Epoch 29/100, Loss: 1.8958934413193762
# Shubham Derhgawen Epoch 30/100, Loss: 1.7956597213530703
# Shubham Derhgawen Epoch 31/100, Loss: 1.8301324226692206
# Shubham Derhgawen Epoch 32/100, Loss: 1.645052822825955
# Shubham Derhgawen Epoch 33/100, Loss: 1.6649528916291712
# Shubham Derhgawen Epoch 34/100, Loss: 1.8388304597059797
# Shubham Derhgawen Epoch 35/100, Loss: 1.7225475810051634
# Shubham Derhgawen Epoch 36/100, Loss: 1.5734169140544045
# Shubham Derhgawen Epoch 37/100, Loss: 1.8435192419931892
# Shubham Derhgawen Epoch 38/100, Loss: 1.86344371241543
# Shubham Derhgawen Epoch 39/100, Loss: 1.7345985612368224
# Shubham Derhgawen Epoch 40/100, Loss: 1.6570870132113253
# Shubham Derhgawen Epoch 41/100, Loss: 1.564330309675341
# Shubham Derhgawen Epoch 42/100, Loss: 1.6062879238858883
# Shubham Derhgawen Epoch 43/100, Loss: 1.6524947914637973
# Shubham Derhgawen Epoch 44/100, Loss: 1.6555412352679681
# Shubham Derhgawen Epoch 45/100, Loss: 1.6779902807707638
# Shubham Derhgawen Epoch 46/100, Loss: 1.5409793998819006
# Shubham Derhgawen Epoch 47/100, Loss: 1.5831106542550377
# Shubham Derhgawen Epoch 48/100, Loss: 1.5769762350380734
# Shubham Derhgawen Epoch 49/100, Loss: 1.4585079560226262
# Shubham Derhgawen Epoch 50/100, Loss: 1.4609556212113688
# Shubham Derhgawen Epoch 51/100, Loss: 1.471720372928019
# Shubham Derhgawen Epoch 52/100, Loss: 1.381230416453802
# Shubham Derhgawen Epoch 53/100, Loss: 1.4095385310233262
# Shubham Derhgawen Epoch 54/100, Loss: 1.5287150326884031
# Shubham Derhgawen Epoch 55/100, Loss: 1.4883433580047025
# Shubham Derhgawen Epoch 56/100, Loss: 1.3603544446080746
# Shubham Derhgawen Epoch 57/100, Loss: 1.4075943345162383
# Shubham Derhgawen Epoch 58/100, Loss: 1.4901507758062484
# Shubham Derhgawen Epoch 59/100, Loss: 1.543457770850369
# Shubham Derhgawen Epoch 60/100, Loss: 1.3603144332154524
# Shubham Derhgawen Epoch 61/100, Loss: 1.3763129089829444
# Shubham Derhgawen Epoch 62/100, Loss: 1.3929243887635632
# Shubham Derhgawen Epoch 63/100, Loss: 1.3317825387880595
# Shubham Derhgawen Epoch 64/100, Loss: 1.454158630099467
# Shubham Derhgawen Epoch 65/100, Loss: 1.2712038819708111
# Shubham Derhgawen Epoch 66/100, Loss: 1.445422808122238
# Shubham Derhgawen Epoch 67/100, Loss: 1.4885783424414076
# Shubham Derhgawen Epoch 68/100, Loss: 1.434953599709482
# Shubham Derhgawen Epoch 69/100, Loss: 1.4416297616589753
# Shubham Derhgawen Epoch 70/100, Loss: 1.3495290499815964
# Shubham Derhgawen Epoch 71/100, Loss: 1.3395153090214493
# Shubham Derhgawen Epoch 72/100, Loss: 1.2916197192780101
# Shubham Derhgawen Epoch 73/100, Loss: 1.2221477645159786
# Shubham Derhgawen Epoch 74/100, Loss: 1.4519671900375328
# Shubham Derhgawen Epoch 75/100, Loss: 1.1787587600215792
# Shubham Derhgawen Epoch 76/100, Loss: 1.2898813120956412
# Shubham Derhgawen Epoch 77/100, Loss: 1.1949295215970066
# Shubham Derhgawen Epoch 78/100, Loss: 1.2670310090869328
# Shubham Derhgawen Epoch 79/100, Loss: 1.294074617239922
# Shubham Derhgawen Epoch 80/100, Loss: 1.261958700630339
# Shubham Derhgawen Epoch 81/100, Loss: 1.0676035546030738
# Shubham Derhgawen Epoch 82/100, Loss: 1.2433750718083547
# Shubham Derhgawen Epoch 83/100, Loss: 1.1989157072605647
# Shubham Derhgawen Epoch 84/100, Loss: 1.4369950093178945
# Shubham Derhgawen Epoch 85/100, Loss: 1.1590933119455389
# Shubham Derhgawen Epoch 86/100, Loss: 1.2257675519004343
# Shubham Derhgawen Epoch 87/100, Loss: 1.3985518184089654
# Shubham Derhgawen Epoch 88/100, Loss: 1.2311731726910033
# Shubham Derhgawen Epoch 89/100, Loss: 1.225288703742879
# Shubham Derhgawen Epoch 90/100, Loss: 1.2301957170944742
# Shubham Derhgawen Epoch 91/100, Loss: 1.2490957883975953
# Shubham Derhgawen Epoch 92/100, Loss: 1.2228271969239353
# Shubham Derhgawen Epoch 93/100, Loss: 1.2169646253347062
# Shubham Derhgawen Epoch 94/100, Loss: 1.211135013622405
# Shubham Derhgawen Epoch 95/100, Loss: 1.1477814274832554
# Shubham Derhgawen Epoch 96/100, Loss: 1.1266000234638964
# Shubham Derhgawen Epoch 97/100, Loss: 1.177767226627561
# Shubham Derhgawen Epoch 98/100, Loss: 1.1996284677596996
# Shubham Derhgawen Epoch 99/100, Loss: 1.1981911567866912
# Shubham Derhgawen Epoch 100/100, Loss: 1.1186210075610368

# %%
epochs = 200
W1, W2, total_loss = train_skip_gram_negative_sampling(corpus, word_to_index, vocab_size, embedding_dim, learning_rate, epochs, num_neg_samples)
plot_embedding(W1, vocab)
plot_loss_over_epochs(total_loss, epochs)
plot_cosine_similarity(W2, vocab)
# Out:
# Shubham Derhgawen Epoch 1/200, Loss: 2.442930184238408
# Shubham Derhgawen Epoch 2/200, Loss: 2.3230244607351924
# Shubham Derhgawen Epoch 3/200, Loss: 2.298738565932208
# Shubham Derhgawen Epoch 4/200, Loss: 2.1736998381247448
# Shubham Derhgawen Epoch 5/200, Loss: 2.222873026614854
# Shubham Derhgawen Epoch 6/200, Loss: 2.1332043749960112
# Shubham Derhgawen Epoch 7/200, Loss: 2.1223551069907867
# Shubham Derhgawen Epoch 8/200, Loss: 2.1497270816005685
# Shubham Derhgawen Epoch 9/200, Loss: 2.102181500562419
# Shubham Derhgawen Epoch 10/200, Loss: 2.08389584197874
# Shubham Derhgawen Epoch 11/200, Loss: 2.043151915132284
# Shubham Derhgawen Epoch 12/200, Loss: 1.9882516512702417
# Shubham Derhgawen Epoch 13/200, Loss: 1.907900646002788
# Shubham Derhgawen Epoch 14/200, Loss: 1.9158516472985827
# Shubham Derhgawen Epoch 15/200, Loss: 2.00497917511541
# Shubham Derhgawen Epoch 16/200, Loss: 2.067262948379301
# Shubham Derhgawen Epoch 17/200, Loss: 1.95590229615406
# Shubham Derhgawen Epoch 18/200, Loss: 1.8494993803378605
# Shubham Derhgawen Epoch 19/200, Loss: 1.9197416125540372
# Shubham Derhgawen Epoch 20/200, Loss: 1.8291825939946444
# Shubham Derhgawen Epoch 21/200, Loss: 2.079011161263091
# Shubham Derhgawen Epoch 22/200, Loss: 1.9147252854478036
# Shubham Derhgawen Epoch 23/200, Loss: 1.9094915532905063
# Shubham Derhgawen Epoch 24/200, Loss: 1.8401233016359833
# Shubham Derhgawen Epoch 25/200, Loss: 1.8703876886229012
# Shubham Derhgawen Epoch 26/200, Loss: 1.8036129707437354
# Shubham Derhgawen Epoch 27/200, Loss: 1.8567329058446849
# Shubham Derhgawen Epoch 28/200, Loss: 1.7981450860528234
# Shubham Derhgawen Epoch 29/200, Loss: 1.772109660164297
# Shubham Derhgawen Epoch 30/200, Loss: 1.8367840112209506
# Shubham Derhgawen Epoch 31/200, Loss: 1.7364654891268914
# Shubham Derhgawen Epoch 32/200, Loss: 1.5821641607130261
# Shubham Derhgawen Epoch 33/200, Loss: 1.7276682399544252
# Shubham Derhgawen Epoch 34/200, Loss: 1.81735800955116
# Shubham Derhgawen Epoch 35/200, Loss: 1.7899336450234693
# Shubham Derhgawen Epoch 36/200, Loss: 1.7659997846453326
# Shubham Derhgawen Epoch 37/200, Loss: 1.729402731094682
# Shubham Derhgawen Epoch 38/200, Loss: 1.7195471099444153
# Shubham Derhgawen Epoch 39/200, Loss: 1.6729108981865903
# Shubham Derhgawen Epoch 40/200, Loss: 1.651450912316811
# Shubham Derhgawen Epoch 41/200, Loss: 1.766556089603738
# Shubham Derhgawen Epoch 42/200, Loss: 1.8282541752953303
# Shubham Derhgawen Epoch 43/200, Loss: 1.5933500527293412
# Shubham Derhgawen Epoch 44/200, Loss: 1.4566220079920238
# Shubham Derhgawen Epoch 45/200, Loss: 1.6566175504273555
# Shubham Derhgawen Epoch 46/200, Loss: 1.4986594887557785
# Shubham Derhgawen Epoch 47/200, Loss: 1.801405235149981
# Shubham Derhgawen Epoch 48/200, Loss: 1.5434798627035367
# Shubham Derhgawen Epoch 49/200, Loss: 1.7798485869021001
# Shubham Derhgawen Epoch 50/200, Loss: 1.4516454007266022
# Shubham Derhgawen Epoch 51/200, Loss: 1.6905090487490337
# Shubham Derhgawen Epoch 52/200, Loss: 1.651643448505509
# Shubham Derhgawen Epoch 53/200, Loss: 1.4737389256290365
# Shubham Derhgawen Epoch 54/200, Loss: 1.5515486287977485
# Shubham Derhgawen Epoch 55/200, Loss: 1.4354772134128846
# Shubham Derhgawen Epoch 56/200, Loss: 1.7250109317859308
# Shubham Derhgawen Epoch 57/200, Loss: 1.5790690712940834
# Shubham Derhgawen Epoch 58/200, Loss: 1.62529454779929
# Shubham Derhgawen Epoch 59/200, Loss: 1.6063199817371843
# Shubham Derhgawen Epoch 60/200, Loss: 1.51476232261138
# Shubham Derhgawen Epoch 61/200, Loss: 1.4860202016425834
# Shubham Derhgawen Epoch 62/200, Loss: 1.466158241705526
# Shubham Derhgawen Epoch 63/200, Loss: 1.5357442870401568
# Shubham Derhgawen Epoch 64/200, Loss: 1.714839440604548
# Shubham Derhgawen Epoch 65/200, Loss: 1.3594428515058645
# Shubham Derhgawen Epoch 66/200, Loss: 1.507943289463683
# Shubham Derhgawen Epoch 67/200, Loss: 1.6844095847930824
# Shubham Derhgawen Epoch 68/200, Loss: 1.5948253590488013
# Shubham Derhgawen Epoch 69/200, Loss: 1.5030986305191965
# Shubham Derhgawen Epoch 70/200, Loss: 1.4978321266541244
# Shubham Derhgawen Epoch 71/200, Loss: 1.6172885199115057
# Shubham Derhgawen Epoch 72/200, Loss: 1.5864358423888272
# Shubham Derhgawen Epoch 73/200, Loss: 1.5321137541994259
# Shubham Derhgawen Epoch 74/200, Loss: 1.47773597470745
# Shubham Derhgawen Epoch 75/200, Loss: 1.4558376769380756
# Shubham Derhgawen Epoch 76/200, Loss: 1.545851936070257
# Shubham Derhgawen Epoch 77/200, Loss: 1.4044795862732056
# Shubham Derhgawen Epoch 78/200, Loss: 1.3471628275454808
# Shubham Derhgawen Epoch 79/200, Loss: 1.352732930855106
# Shubham Derhgawen Epoch 80/200, Loss: 1.5390397151167694
# Shubham Derhgawen Epoch 81/200, Loss: 1.4271964465667164
# Shubham Derhgawen Epoch 82/200, Loss: 1.2267915236893652
# Shubham Derhgawen Epoch 83/200, Loss: 1.4453766094033127
# Shubham Derhgawen Epoch 84/200, Loss: 1.4701405337914584
# Shubham Derhgawen Epoch 85/200, Loss: 1.469768358506562
# Shubham Derhgawen Epoch 86/200, Loss: 1.2434561299983966
# Shubham Derhgawen Epoch 87/200, Loss: 1.4922304233841772
# Shubham Derhgawen Epoch 88/200, Loss: 1.3121605972950838
# Shubham Derhgawen Epoch 89/200, Loss: 1.33443240859989
# Shubham Derhgawen Epoch 90/200, Loss: 1.3806369216171468
# Shubham Derhgawen Epoch 91/200, Loss: 1.3689095705011418
# Shubham Derhgawen Epoch 92/200, Loss: 1.2854712581803371
# Shubham Derhgawen Epoch 93/200, Loss: 1.3688101451948427
# Shubham Derhgawen Epoch 94/200, Loss: 1.1885860726231268
# Shubham Derhgawen Epoch 95/200, Loss: 1.290608423126828
# Shubham Derhgawen Epoch 96/200, Loss: 1.1366973178306903
# Shubham Derhgawen Epoch 97/200, Loss: 1.4583746031945002
# Shubham Derhgawen Epoch 98/200, Loss: 1.3026954802080435
# Shubham Derhgawen Epoch 99/200, Loss: 1.2642231669546682
# Shubham Derhgawen Epoch 100/200, Loss: 1.2473539915960512
# Shubham Derhgawen Epoch 101/200, Loss: 1.3426719699018987
# Shubham Derhgawen Epoch 102/200, Loss: 1.3430247334554812
# Shubham Derhgawen Epoch 103/200, Loss: 1.2631222930188784
# Shubham Derhgawen Epoch 104/200, Loss: 1.0590410417959675
# Shubham Derhgawen Epoch 105/200, Loss: 1.2569952228682284
# Shubham Derhgawen Epoch 106/200, Loss: 1.2108529601194955
# Shubham Derhgawen Epoch 107/200, Loss: 1.2377190562367184
# Shubham Derhgawen Epoch 108/200, Loss: 1.184955706446336
# Shubham Derhgawen Epoch 109/200, Loss: 1.2338173138825002
# Shubham Derhgawen Epoch 110/200, Loss: 1.1324235142070385
# Shubham Derhgawen Epoch 111/200, Loss: 1.0903360822831745
# Shubham Derhgawen Epoch 112/200, Loss: 1.1067619330996945
# Shubham Derhgawen Epoch 113/200, Loss: 1.2114876264175052
# Shubham Derhgawen Epoch 114/200, Loss: 1.2221163488747528
# Shubham Derhgawen Epoch 115/200, Loss: 1.2645484116483208
# Shubham Derhgawen Epoch 116/200, Loss: 1.1364598069031462
# Shubham Derhgawen Epoch 117/200, Loss: 1.3075365493559772
# Shubham Derhgawen Epoch 118/200, Loss: 1.1526148100343048
# Shubham Derhgawen Epoch 119/200, Loss: 1.2386375203701698
# Shubham Derhgawen Epoch 120/200, Loss: 1.1493623864558615
# Shubham Derhgawen Epoch 121/200, Loss: 1.0665657096316639
# Shubham Derhgawen Epoch 122/200, Loss: 1.1205490971329826
# Shubham Derhgawen Epoch 123/200, Loss: 1.2149090881033975
# Shubham Derhgawen Epoch 124/200, Loss: 1.0430697142757035
# Shubham Derhgawen Epoch 125/200, Loss: 1.1459954937066246
# Shubham Derhgawen Epoch 126/200, Loss: 1.1428525148321105
# Shubham Derhgawen Epoch 127/200, Loss: 1.2178399727527722
# Shubham Derhgawen Epoch 128/200, Loss: 1.1298363803431926
# Shubham Derhgawen Epoch 129/200, Loss: 1.0059971458080217
# Shubham Derhgawen Epoch 130/200, Loss: 0.985945221742704
# Shubham Derhgawen Epoch 131/200, Loss: 1.0581708305567687
# Shubham Derhgawen Epoch 132/200, Loss: 1.0629976113515507
# Shubham Derhgawen Epoch 133/200, Loss: 1.1560129341441017
# Shubham Derhgawen Epoch 134/200, Loss: 0.8941277989845636
# Shubham Derhgawen Epoch 135/200, Loss: 1.050568435265282
# Shubham Derhgawen Epoch 136/200, Loss: 1.137284491183893
# Shubham Derhgawen Epoch 137/200, Loss: 1.250186608923833
# Shubham Derhgawen Epoch 138/200, Loss: 1.127747481142747
# Shubham Derhgawen Epoch 139/200, Loss: 1.108548637275034
# Shubham Derhgawen Epoch 140/200, Loss: 1.1802584301103933
# Shubham Derhgawen Epoch 141/200, Loss: 0.9264457403406168
# Shubham Derhgawen Epoch 142/200, Loss: 1.1641695504706873
# Shubham Derhgawen Epoch 143/200, Loss: 0.9946696395163303
# Shubham Derhgawen Epoch 144/200, Loss: 1.0041918941450512
# Shubham Derhgawen Epoch 145/200, Loss: 1.0735353810099628
# Shubham Derhgawen Epoch 146/200, Loss: 0.9658050808200953
# Shubham Derhgawen Epoch 147/200, Loss: 1.1737885349952704
# Shubham Derhgawen Epoch 148/200, Loss: 0.8976580533229604
# Shubham Derhgawen Epoch 149/200, Loss: 1.11144533410587
# Shubham Derhgawen Epoch 150/200, Loss: 0.9405508499348629
# Shubham Derhgawen Epoch 151/200, Loss: 1.205062904757549
# Shubham Derhgawen Epoch 152/200, Loss: 1.192009772537023
# Shubham Derhgawen Epoch 153/200, Loss: 1.0072569389717667
# Shubham Derhgawen Epoch 154/200, Loss: 1.0909631494771452
# Shubham Derhgawen Epoch 155/200, Loss: 1.0915697563732776
# Shubham Derhgawen Epoch 156/200, Loss: 0.8928389035338059
# Shubham Derhgawen Epoch 157/200, Loss: 0.8725880965706331
# Shubham Derhgawen Epoch 158/200, Loss: 1.0241080165888166
# Shubham Derhgawen Epoch 159/200, Loss: 1.1300580891613348
# Shubham Derhgawen Epoch 160/200, Loss: 1.2174534598007194
# Shubham Derhgawen Epoch 161/200, Loss: 1.121096727405155
# Shubham Derhgawen Epoch 162/200, Loss: 1.0675789518243195
# Shubham Derhgawen Epoch 163/200, Loss: 1.1526861286059709
# Shubham Derhgawen Epoch 164/200, Loss: 0.9594930708906879
# Shubham Derhgawen Epoch 165/200, Loss: 0.9198577631927825
# Shubham Derhgawen Epoch 166/200, Loss: 1.2030762088819427
# Shubham Derhgawen Epoch 167/200, Loss: 1.2415015987213307
# Shubham Derhgawen Epoch 168/200, Loss: 1.1833662435535461
# Shubham Derhgawen Epoch 169/200, Loss: 1.0825606263905319
# Shubham Derhgawen Epoch 170/200, Loss: 1.0115050583132676
# Shubham Derhgawen Epoch 171/200, Loss: 0.953060387141317
# Shubham Derhgawen Epoch 172/200, Loss: 0.947742210164586
# Shubham Derhgawen Epoch 173/200, Loss: 1.0393166644788612
# Shubham Derhgawen Epoch 174/200, Loss: 0.9847315800698586
# Shubham Derhgawen Epoch 175/200, Loss: 1.1823287964348634
# Shubham Derhgawen Epoch 176/200, Loss: 1.126569928207577
# Shubham Derhgawen Epoch 177/200, Loss: 0.954125300154093
# Shubham Derhgawen Epoch 178/200, Loss: 1.129601685430045
# Shubham Derhgawen Epoch 179/200, Loss: 1.0269563415755616
# Shubham Derhgawen Epoch 180/200, Loss: 1.1976662349555514
# Shubham Derhgawen Epoch 181/200, Loss: 1.162817400397626
# Shubham Derhgawen Epoch 182/200, Loss: 1.0734634428758771
# Shubham Derhgawen Epoch 183/200, Loss: 1.1728704411403068
# Shubham Derhgawen Epoch 184/200, Loss: 1.1757976820566753
# Shubham Derhgawen Epoch 185/200, Loss: 0.990326387263481
# Shubham Derhgawen Epoch 186/200, Loss: 1.0221158296628694
# Shubham Derhgawen Epoch 187/200, Loss: 1.1744907233343516
# Shubham Derhgawen Epoch 188/200, Loss: 0.8851452423985142
# Shubham Derhgawen Epoch 189/200, Loss: 1.1685890332167452
# Shubham Derhgawen Epoch 190/200, Loss: 1.281478644229143
# Shubham Derhgawen Epoch 191/200, Loss: 1.035930723105486
# Shubham Derhgawen Epoch 192/200, Loss: 1.125615426520314
# Shubham Derhgawen Epoch 193/200, Loss: 1.1223427181429635
# Shubham Derhgawen Epoch 194/200, Loss: 1.2218299335471057
# Shubham Derhgawen Epoch 195/200, Loss: 1.0710132649448414
# Shubham Derhgawen Epoch 196/200, Loss: 0.9441290533145427
# Shubham Derhgawen Epoch 197/200, Loss: 1.3107812600153816
# Shubham Derhgawen Epoch 198/200, Loss: 1.0331519766369905
# Shubham Derhgawen Epoch 199/200, Loss: 1.1317691580390739
# Shubham Derhgawen Epoch 200/200, Loss: 1.1051823142195871

# %% [markdown]
# ### 10.Use Pre-trained Word2Vector Model (10pt)
#
# In this section, you should use pretrained GloVe word embeddings from the gensim library to compute the semantic similarity between sentences.

# %%
# !pip install -U gensim
import os
os.kill(os.getpid(),9)
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.5 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 69.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 84.4 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 16.0 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
import numpy as np
from nltk.tokenize import word_tokenize
import gensim.downloader
import nltk
import string
from nltk.corpus import stopwords

nltk.download('punkt_tab')
nltk.download('stopwords')

# List all pretrained embedding models
print(list(gensim.downloader.info()['models'].keys()))

# Download the "glove-twitter-25" embeddings
models = gensim.downloader.load('glove-twitter-25')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
def review_to_vector(review_text):
    # Tokenize and clean the review
    words = word_tokenize(review_text.lower())
    words = [word for word in words if word not in string.punctuation]
    words = [word for word in words if word not in stopwords.words('english')]

    # Remove words not in vocabulary
    ####! Add your code here
    valid_words = [word for word in words if word in models.key_to_index]

    ####
    if not valid_words:
        return np.zeros(models.vector_size)

    # Average word vectors
    ####! Add your code here
    word_vectors = [models[word] for word in valid_words]
    avg_vec =np.mean(word_vectors, axis=0)
    ####
    return avg_vec

def cosine_similarity(vec1, vec2):
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# %%
# Three Sentences.
sent1 = "The cat is sleeping on the sofa."
sent2 = "A cat is napping on the couch."
sent3 = "The spaceship landed on Mars after a six-month journey."

# Convert reviews to vectors
vec1 = review_to_vector(sent1)
vec2 = review_to_vector(sent2)
vec3 = review_to_vector(sent3)

# Calculate similarities
sim1 = cosine_similarity(vec1, vec2)
sim2 = cosine_similarity(vec1, vec3)

print(f"sent1-sent2 similarity: {sim1:.4f}")
print(f"sent1-sent3 similarity: {sim2:.4f}")
# Out:
# sent1-sent2 similarity: 0.9441
# sent1-sent3 similarity: 0.6561
